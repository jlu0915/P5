# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import missingno as msno

import datetime as dt

# %%
#l'étape où on crée des nouvelles features, ca s'appelle 'feature engenring'donc j'explore mes tables , 
#je construis mon dataset et je fais mes features engenering en meme temps, en suite , on commence les nouveaux 
#modèles, tj dans ma vie de datascientiste je fais comme ca

#en datascience , normalement on crée des variables puis on teste avec les modèles voir lesquels notre modèle préfére
#mais ici , rfm est imposé , cela considère comme une introduction de datascience

# %%
#donc ce que je dois faire là, je dois compléter mon dataset pour que ce soit plus complète possible 



#faire k-means rfm, plein d'aurtre truc par rapport au dataset final 
#récence
#fréquence
#montant toal 
#minimum montant d'achat 
#maximum montant d'achat 
#moyenne montant d'achat 
#moyenne review score 
#minimum review score 
#maximum review score 
#

# %%
#montant total
#montant moyenne 
#min montant 
#max montant
#coder le payment instantané 
#le payment par quel type de carte
#nb fois de paiement (je peux faire une fois / plusieur fois) ou une fois/ deux fois et plusieurs fois
#la fréquence (le nb total des cdes)
#la récence 
#mes catégories de mes produits acheté (home(linge,décor,maison)/fourniture/hobbis/technologie/mode/health beaty/food/other) maximum 8 
#parce que c'est une variable catégorielle

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

sn.set(rc={'figure.figsize':[15,15]},font_scale=1.3)

# %%
df_customer = pd.read_csv("olist_customers_dataset.csv")
df_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_customer.customer_id.nunique()
# Out:
# 99441

# %%
df_customer.customer_unique_id.nunique()
# Out:
# 96096

# %%
df_customer.shape
# Out:
# (99441, 5)

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_geolocation = pd.read_csv("olist_geolocation_dataset.csv")
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_geolocation.shape
# Out:
# (1000163, 5)

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_order_item = pd.read_csv("olist_order_items_dataset.csv")
df_order_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
df_order_item.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %%
df_order_item.shape
# Out:
# (112650, 7)

# %%
df_order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
df_order_item.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %%
df_order_payment = pd.read_csv("olist_order_payments_dataset.csv")
df_order_payment.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_order_payment.shape
# Out:
# (103886, 5)

# %%
df_order_payment.order_id.nunique()
# Out:
# 99440

# %%
df_order_payment.shape
# Out:
# (103886, 5)

# %%
df_order_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_order_review = pd.read_csv("olist_order_reviews_dataset.csv")
df_order_review.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
df_order_review.nunique()
# Out:
# review_id                  98410
# order_id                   98673
# review_score                   5
# review_comment_title        4527
# review_comment_message     36159
# review_creation_date         636
# review_answer_timestamp    98248
# dtype: int64

# %%
df_order_review.shape
# Out:
# (99224, 7)

# %%
df_order_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
df_order_review['review_comment_message'].fillna("no comme", inplace=True)
df_order_review =df_order_review.drop(['review_comment_title'],axis=1)
df_order_review = df_order_review.dropna()

# %%
df_order = pd.read_csv("olist_orders_dataset.csv")
df_order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
df_order.nunique()
# Out:
# order_id                         99441
# customer_id                      99441
# order_status                         8
# order_purchase_timestamp         98875
# order_approved_at                90733
# order_delivered_carrier_date     81018
# order_delivered_customer_date    95664
# order_estimated_delivery_date      459
# dtype: int64

# %%
df_order.shape
# Out:
# (99441, 8)

# %%
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df_product = pd.read_csv("olist_products_dataset.csv")
df_product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
df_product.shape
# Out:
# (32951, 9)

# %%
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df_seller = pd.read_csv("olist_sellers_dataset.csv")
df_seller.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
df_seller.nunique()
# Out:
# seller_id                 3095
# seller_zip_code_prefix    2246
# seller_city                611
# seller_state                23
# dtype: int64

# %%
df_seller.shape
# Out:
# (3095, 4)

# %%
df_seller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
df_product_category_translation = pd.read_csv("product_category_name_translation.csv")
df_product_category_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_product_category_translation.shape
# Out:
# (71, 2)

# %%
df_product_category_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
df_product = (df_product.merge(df_product_category_translation, how = 'left' , on = 'product_category_name'))
df_product = df_product.drop('product_category_name', axis=1)
df_product.rename(columns = {'product_category_name_english': 'product_category_name'}, inplace = True)
df_product = df_product[['product_id','product_category_name','product_name_lenght','product_description_lenght','product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm']]

# %%
df_product.head()
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumery
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   art
# 2  96bd76ec8810374ed1b65e291975717f        sports_leisure
# 3  cef67bcfe19066a932b7673e239eb23d                  baby
# 4  9dc1a7de274444849c219cff195d0b71            housewares
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
df_main = (
            # The main df is based on the order dataframe
            df_order
    
                # Merge order payment dataframe
                .merge(df_order_payment, how='left', on='order_id')
           
                # Merge order item dataframe
                .merge(df_order_item, how='left', on='order_id')
    
                #Merge order review dataframe
                .merge(df_order_review,how='left',on = 'order_id')
                
                #Merge product dataframe
                .merge(df_product,how='left',on = 'product_id')
    
                #Merge customer dataframe
                .merge(df_customer,how = 'left',on = 'customer_id')
    
                #Merge seller dataframe
                .merge(df_seller, how = 'left', on = 'seller_id')

)

# %%
df_main.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0           2017-10-18 00:00:00                 1.0  credit_card
# 1           2017-10-18 00:00:00                 3.0      voucher
# 2           2017-10-18 00:00:00                 2.0      voucher
# 3           2018-08-13 00:00:00                 1.0       boleto
# 4           2018-09-04 00:00:00                 1.0  credit_card
#
#    payment_installments  payment_value  order_item_id  \
# 0                   1.0          18.12            1.0
# 1                   1.0           2.00            1.0
# 2                   1.0          18.59            1.0
# 3                   1.0         141.46            1.0
# 4                   3.0         179.12            1.0
#
#                          product_id                         seller_id  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 1  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 2  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9
# 3  595fac2a385ac33a80bd5114aec74eb8  289cdb325fb7e7f891c38608bf9e0962
# 4  aa4383b373c6aca5d8797843e5594415  4869f7a5dfa277a7dca6462dcf3b52b2
#
#    shipping_limit_date   price  freight_value  \
# 0  2017-10-06 11:07:15   29.99           8.72
# 1  2017-10-06 11:07:15   29.99           8.72
# 2  2017-10-06 11:07:15   29.99           8.72
# 3  2018-07-30 03:24:27  118.70          22.76
# 4  2018-08-13 08:55:23  159.90          19.22
#
#                           review_id  review_score  \
# 0  a54f0611adc9ed256b57ede6b6eb5114           4.0
# 1  a54f0611adc9ed256b57ede6b6eb5114           4.0
# 2  a54f0611adc9ed256b57ede6b6eb5114           4.0
# 3  8d5266042046a06655c8db133d120ba5           4.0
# 4  e73b67b67587f7644d5bd1a52deb1b01           5.0
#
#                               review_comment_message review_creation_date  \
# 0  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 1  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 2  Não testei o produto ainda, mas ele veio corre...  2017-10-11 00:00:00
# 3                               Muito bom o produto.  2018-08-08 00:00:00
# 4                                           no comme  2018-08-18 00:00:00
#
#   review_answer_timestamp product_category_name  product_name_lenght  \
# 0     2017-10-12 03:43:48            housewares                 40.0
# 1     2017-10-12 03:43:48            housewares                 40.0
# 2     2017-10-12 03:43:48            housewares                 40.0
# 3     2018-08-08 18:37:50             perfumery                 29.0
# 4     2018-08-22 19:07:58                  auto                 46.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       268.0                 4.0             500.0
# 1                       268.0                 4.0             500.0
# 2                       268.0                 4.0             500.0
# 3                       178.0                 1.0             400.0
# 4                       232.0                 1.0             420.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               19.0                8.0              13.0
# 1               19.0                8.0              13.0
# 2               19.0                8.0              13.0
# 3               19.0               13.0              19.0
# 4               24.0               19.0              21.0
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 3  af07308b275d755c9edb36a90c618231                     47813     barreiras
# 4  3a653a41f6f9fc3d2a113cf8398680e8                     75265    vianopolis
#
#   customer_state  seller_zip_code_prefix     seller_city seller_state
# 0             SP                  9350.0            maua           SP
# 1             SP                  9350.0            maua           SP
# 2             SP                  9350.0            maua           SP
# 3             BA                 31570.0  belo horizonte           SP
# 4             GO                 14840.0         guariba           SP

# %%
df_main = df_main[df_main['payment_type'] != 'not_defined']

# %%
df_main[df_main['payment_type'].isna()]
# Out:
#                                order_id                       customer_id  \
# 36864  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 36865  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 36866  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 36864    delivered      2016-09-15 12:16:38  2016-09-15 12:16:38
# 36865    delivered      2016-09-15 12:16:38  2016-09-15 12:16:38
# 36866    delivered      2016-09-15 12:16:38  2016-09-15 12:16:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 36864          2016-11-07 17:11:53           2016-11-09 07:47:38
# 36865          2016-11-07 17:11:53           2016-11-09 07:47:38
# 36866          2016-11-07 17:11:53           2016-11-09 07:47:38
#
#       order_estimated_delivery_date  payment_sequential payment_type  \
# 36864           2016-10-04 00:00:00                 NaN          NaN
# 36865           2016-10-04 00:00:00                 NaN          NaN
# 36866           2016-10-04 00:00:00                 NaN          NaN
#
#        payment_installments  payment_value  order_item_id  \
# 36864                   NaN            NaN            1.0
# 36865                   NaN            NaN            2.0
# 36866                   NaN            NaN            3.0
#
#                              product_id                         seller_id  \
# 36864  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 36865  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 36866  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
#
#        shipping_limit_date  price  freight_value  \
# 36864  2016-09-19 23:11:33  44.99           2.83
# 36865  2016-09-19 23:11:33  44.99           2.83
# 36866  2016-09-19 23:11:33  44.99           2.83
#
#                               review_id  review_score  \
# 36864  6916ca4502d6d3bfd39818759d55d536           1.0
# 36865  6916ca4502d6d3bfd39818759d55d536           1.0
# 36866  6916ca4502d6d3bfd39818759d55d536           1.0
#
#                                review_comment_message review_creation_date  \
# 36864  nao recebi o produto e nem resposta da empresa  2016-10-06 00:00:00
# 36865  nao recebi o produto e nem resposta da empresa  2016-10-06 00:00:00
# 36866  nao recebi o produto e nem resposta da empresa  2016-10-06 00:00:00
#
#       review_answer_timestamp product_category_name  product_name_lenght  \
# 36864     2016-10-07 18:32:28         health_beauty                 34.0
# 36865     2016-10-07 18:32:28         health_beauty                 34.0
# 36866     2016-10-07 18:32:28         health_beauty                 34.0
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 36864                      1036.0                 1.0            1000.0
# 36865                      1036.0                 1.0            1000.0
# 36866                      1036.0                 1.0            1000.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 36864               16.0               16.0              16.0
# 36865               16.0               16.0              16.0
# 36866               16.0               16.0              16.0
#
#                      customer_unique_id  customer_zip_code_prefix  \
# 36864  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
# 36865  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
# 36866  830d5b7aaa3b6f1e9ad63703bec97d23                     14600
#
#               customer_city customer_state  seller_zip_code_prefix  \
# 36864  sao joaquim da barra             SP                 81810.0
# 36865  sao joaquim da barra             SP                 81810.0
# 36866  sao joaquim da barra             SP                 81810.0
#
#       seller_city seller_state
# 36864    curitiba           PR
# 36865    curitiba           PR
# 36866    curitiba           PR

# %%
df_main.dropna(subset=['payment_type'], inplace=True)

# %%
PaymentType = df_main['payment_type'].value_counts().head(57).to_frame()
PaymentType.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_ea864_row0_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_ea864_row1_col0{
#             background-color:  #fcbca2;
#             color:  #000000;
#         }#T_ea864_row2_col0{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_ea864_row3_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_ea864_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >payment_type</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea864_level0_row0" class="row_heading level0 row0" >credit_card</th>
#                         <td id="T_ea864_row0_col0" class="data row0 col0" >87776</td>
#             </tr>
#             <tr>
#                         <th id="T_ea864_level0_row1" class="row_heading level0 row1" >boleto</th>
#                         <td id="T_ea864_row1_col0" class="data row1 col0" >23190</td>
#             </tr>
#             <tr>
#                         <th id="T_ea864_level0_row2" class="row_heading level0 row2" >voucher</th>
#                         <td id="T_ea864_row2_col0" class="data row2 col0" >6465</td>
#             </tr>
#             <tr>
#                         <th id="T_ea864_level0_row3" class="row_heading level0 row3" >debit_card</th>
#                         <td id="T_ea864_row3_col0" class="data row3 col0" >1706</td>
#             </tr>
#     </tbody></table>

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119137 entries, 0 to 119142
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119137 non-null  object
#  1   customer_id                    119137 non-null  object
#  2   order_status                   119137 non-null  object
#  3   order_purchase_timestamp       119137 non-null  object
#  4   order_approved_at              118963 non-null  object
#  5   order_delivered_carrier_date   117054 non-null  object
#  6   order_delivered_customer_date  115719 non-null  object
#  7   order_estimated_delivery_date  119137 non-null  object
#  8   payment_sequential             119137 non-null  float64
#  9   payment_type                   119137 non-null  object
#  10  payment_installments           119137 non-null  float64
#  11  payment_value                  119137 non-null  float64
#  12  order_item_id                  118307 non-null  float64
#  13  product_id                     118307 non-null  object
#  14  seller_id                      118307 non-null  object
#  15  shipping_limit_date            118307 non-null  object
#  16  price                          118307 non-null  float64
#  17  freight_value                  118307 non-null  float64
#  18  review_id                      118140 non-null  object
#  19  review_score                   118140 non-null  float64
#  20  review_comment_message         118140 non-null  object
#  21  review_creation_date           118140 non-null  object
#  22  review_answer_timestamp        118140 non-null  object
#  23  product_category_name          116573 non-null  object
#  24  product_name_lenght            116598 non-null  float64
#  25  product_description_lenght     116598 non-null  float64
#  26  product_photos_qty             116598 non-null  float64
#  27  product_weight_g               118287 non-null  float64
#  28  product_length_cm              118287 non-null  float64
#  29  product_height_cm              118287 non-null  float64
#  30  product_width_cm               118287 non-null  float64
#  31  customer_unique_id             119137 non-null  object
#  32  customer_zip_code_prefix       119137 non-null  int64
#  33  customer_city                  119137 non-null  object
#  34  customer_state                 119137 non-null  object
#  35  seller_zip_code_prefix         118307 non-null  float64
#  36  seller_city                    118307 non-null  object
#  37  seller_state                   118307 non-null  object
# dtypes: float64(15), int64(1), object(22)
# memory usage: 35.4+ MB

# %%
df_main.shape
# Out:
# (119137, 38)

# %%
df_main.columns.to_list()
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'shipping_limit_date',
#  'price',
#  'freight_value',
#  'review_id',
#  'review_score',
#  'review_comment_message',
#  'review_creation_date',
#  'review_answer_timestamp',
#  'product_category_name',
#  'product_name_lenght',
#  'product_description_lenght',
#  'product_photos_qty',
#  'product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state',
#  'seller_zip_code_prefix',
#  'seller_city',
#  'seller_state']

# %%
df_main.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 174
# order_delivered_carrier_date     2083
# order_delivered_customer_date    3418
# order_estimated_delivery_date       0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# review_id                         997
# review_score                      997
# review_comment_message            997
# review_creation_date              997
# review_answer_timestamp           997
# product_category_name            2564
# product_name_lenght              2539
# product_description_lenght       2539
# product_photos_qty               2539
# product_weight_g                  850
# product_length_cm                 850
# product_height_cm                 850
# product_width_cm                  850
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# seller_zip_code_prefix            830
# seller_city                       830
# seller_state                      830
# dtype: int64

# %%
msno.bar(df_main)
plt.title('Taux de complétion des données',fontsize = 35)
#plt.savefig("Taux de complétion des données.jpg")
# Out:
# Text(0.5, 1.0, 'Taux de complétion des données')

# %%
#regarder le taux remplissage de chaque variable 
df_main.isna().mean().round(1)* 100
# Out:
# order_id                         0.0
# customer_id                      0.0
# order_status                     0.0
# order_purchase_timestamp         0.0
# order_approved_at                0.0
# order_delivered_carrier_date     0.0
# order_delivered_customer_date    0.0
# order_estimated_delivery_date    0.0
# payment_sequential               0.0
# payment_type                     0.0
# payment_installments             0.0
# payment_value                    0.0
# order_item_id                    0.0
# product_id                       0.0
# seller_id                        0.0
# shipping_limit_date              0.0
# price                            0.0
# freight_value                    0.0
# review_id                        0.0
# review_score                     0.0
# review_comment_message           0.0
# review_creation_date             0.0
# review_answer_timestamp          0.0
# product_category_name            0.0
# product_name_lenght              0.0
# product_description_lenght       0.0
# product_photos_qty               0.0
# product_weight_g                 0.0
# product_length_cm                0.0
# product_height_cm                0.0
# product_width_cm                 0.0
# customer_unique_id               0.0
# customer_zip_code_prefix         0.0
# customer_city                    0.0
# customer_state                   0.0
# seller_zip_code_prefix           0.0
# seller_city                      0.0
# seller_state                     0.0
# dtype: float64

# %%
#df_main = df_main.drop(['review_comment_title','review_comment_message'], axis=1)

# %%
df_main.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 174
# order_delivered_carrier_date     2083
# order_delivered_customer_date    3418
# order_estimated_delivery_date       0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# order_item_id                     830
# product_id                        830
# seller_id                         830
# shipping_limit_date               830
# price                             830
# freight_value                     830
# review_id                         997
# review_score                      997
# review_comment_message            997
# review_creation_date              997
# review_answer_timestamp           997
# product_category_name            2564
# product_name_lenght              2539
# product_description_lenght       2539
# product_photos_qty               2539
# product_weight_g                  850
# product_length_cm                 850
# product_height_cm                 850
# product_width_cm                  850
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# seller_zip_code_prefix            830
# seller_city                       830
# seller_state                      830
# dtype: int64

# %%
df_main.shape
# Out:
# (119137, 38)

# %%
df_main.dropna(inplace= True, how='any')

# %%
df_main.isna().sum()

# %%
#df_main.head()

# %%
df_main.shape
# Out:
# (113193, 38)

# %%
#df_temp=df_main[['customer_unique_id','order_id']].groupby('customer_unique_id').sum()

# %%
#df_temp.hea

# %%
df_main.describe().T
# Out:
#                                count          mean           std      min  \
# payment_sequential          113193.0      1.090818      0.686674     1.00
# payment_installments        113193.0      2.943680      2.779181     0.00
# payment_value               113193.0    171.557922    264.197701     0.00
# order_item_id               113193.0      1.195065      0.687526     1.00
# price                       113193.0    119.846650    181.079901     0.85
# freight_value               113193.0     20.002595     15.711728     0.00
# review_score                113193.0      4.082505      1.345924     1.00
# product_name_lenght         113193.0     48.802894     10.016138     5.00
# product_description_lenght  113193.0    784.727183    650.332251     4.00
# product_photos_qty          113193.0      2.206833      1.718331     1.00
# product_weight_g            113193.0   2106.236075   3765.207714     0.00
# product_length_cm           113193.0     30.278091     16.145105     7.00
# product_height_cm           113193.0     16.597422     13.437427     2.00
# product_width_cm            113193.0     23.099679     11.735929     6.00
# customer_zip_code_prefix    113193.0  35085.687437  29867.822574  1003.00
# seller_zip_code_prefix      113193.0  24525.441352  27648.963528  1001.00
#
#                                  25%       50%       75%       max
# payment_sequential              1.00      1.00      1.00     26.00
# payment_installments            1.00      2.00      4.00     24.00
# payment_value                  60.85    107.96    189.15  13664.08
# order_item_id                   1.00      1.00      1.00     21.00
# price                          39.90     74.90    132.98   6735.00
# freight_value                  13.08     16.32     21.19    409.68
# review_score                    4.00      5.00      5.00      5.00
# product_name_lenght            42.00     52.00     57.00     76.00
# product_description_lenght    346.00    600.00    982.00   3992.00
# product_photos_qty              1.00      1.00      3.00     20.00
# product_weight_g              300.00    700.00   1800.00  40425.00
# product_length_cm              18.00     25.00     38.00    105.00
# product_height_cm               8.00     13.00     20.00    105.00
# product_width_cm               15.00     20.00     30.00    118.00
# customer_zip_code_prefix    11310.00  24315.00  58865.00  99980.00
# seller_zip_code_prefix       6429.00  13660.00  28495.00  99730.00

# %%
df_temp = df_main[df_main['order_purchase_timestamp'].dt.year == 2016].sort_values(by='order_purchase_timestamp').copy()
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(df_temp['order_purchase_timestamp'], df_temp['price'])
plt.title('transaction')
plt.show()

# %%
df_temp = df_main[df_main['order_purchase_timestamp'].dt.year == 2017].sort_values(by='order_purchase_timestamp').copy()
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(df_temp['order_purchase_timestamp'], df_temp['price'])
plt.title('transaction')
plt.show()

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# #### création variable 'panier moyenne'

# %%
average_purchase = df_main[['customer_unique_id','price']].groupby(['customer_unique_id']).mean()
average_purchase = average_purchase.rename(columns = {'price': 'average_purchase'})
average_purchase = average_purchase.reset_index()

# %%
average_purchase.head()
# Out:
#                  customer_unique_id  average_purchase
# 0  0000366f3b9a7992bf8c76cfdf3221e2            129.90
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f             18.90
# 2  0000f46a3911fa3c0805444483337064             69.00
# 3  0000f6ccb0745a6a4b88665a16c9f078             25.99
# 4  0004aac84e0df4da2b147fca70cf8255            180.00

# %%
#average_purchase.average_purchase.sort_values(ascending = False)

# %% [markdown]
# #### création variable 'min montant achat'

# %%
min_purchase = df_main[['customer_unique_id','price']].groupby(['customer_unique_id']).min()
min_purchase = min_purchase.rename(columns = {'price': 'min_purchase'})
min_purchase = min_purchase.reset_index()

# %%
min_purchase.head()
# Out:
#                  customer_unique_id  min_purchase
# 0  0000366f3b9a7992bf8c76cfdf3221e2        129.90
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f         18.90
# 2  0000f46a3911fa3c0805444483337064         69.00
# 3  0000f6ccb0745a6a4b88665a16c9f078         25.99
# 4  0004aac84e0df4da2b147fca70cf8255        180.00

# %% [markdown]
# #### création variable 'max montant achat'

# %%
max_purchase = df_main[['customer_unique_id','price']].groupby(['customer_unique_id']).max()
max_purchase = max_purchase.rename(columns = {'price': 'max_purchase'})
max_purchase = max_purchase.reset_index()

# %%
max_purchase.head()
# Out:
#                  customer_unique_id  max_purchase
# 0  0000366f3b9a7992bf8c76cfdf3221e2        129.90
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f         18.90
# 2  0000f46a3911fa3c0805444483337064         69.00
# 3  0000f6ccb0745a6a4b88665a16c9f078         25.99
# 4  0004aac84e0df4da2b147fca70cf8255        180.00

# %% [markdown]
# #### création variable 'nb_acticle'

# %%
nb_item_per_customer = df_main[['customer_unique_id','order_item_id']].groupby(['customer_unique_id']).count()
nb_item_per_customer = nb_item_per_customer.rename(columns = {'order_item_id': 'nb_item_per_customer'})
nb_item_per_customer = nb_item_per_customer.reset_index()

# %%
nb_item_per_customer.head()
# Out:
#                  customer_unique_id  nb_item_per_customer
# 0  0000366f3b9a7992bf8c76cfdf3221e2                     1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f                     1
# 2  0000f46a3911fa3c0805444483337064                     1
# 3  0000f6ccb0745a6a4b88665a16c9f078                     1
# 4  0004aac84e0df4da2b147fca70cf8255                     1

# %% [markdown]
# #### création variable 'nb_commande'

# %%
nb_cde_per_customer = df_main[['customer_unique_id','order_id']].groupby(['customer_unique_id']).count()
nb_cde_per_customer = nb_cde_per_customer.rename(columns = {'order_id': 'nb_cde_per_customer'})
nb_cde_per_customer = nb_cde_per_customer.reset_index()

# %%
nb_cde_per_customer.head()
# Out:
#                  customer_unique_id  nb_cde_per_customer
# 0  0000366f3b9a7992bf8c76cfdf3221e2                    1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f                    1
# 2  0000f46a3911fa3c0805444483337064                    1
# 3  0000f6ccb0745a6a4b88665a16c9f078                    1
# 4  0004aac84e0df4da2b147fca70cf8255                    1

# %% [markdown]
# #### création variable 'note moyenne'

# %%
average_review_score = df_main[['customer_unique_id','review_score']].groupby(['customer_unique_id']).mean()
average_review_score = average_review_score.rename(columns = {'review_score': 'average_review_score'})
average_review_score = average_review_score.reset_index()

# %%
average_review_score.head()
# Out:
#                  customer_unique_id  average_review_score
# 0  0000366f3b9a7992bf8c76cfdf3221e2                   5.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f                   4.0
# 2  0000f46a3911fa3c0805444483337064                   3.0
# 3  0000f6ccb0745a6a4b88665a16c9f078                   4.0
# 4  0004aac84e0df4da2b147fca70cf8255                   5.0

# %% [markdown]
# #### création variable 'min note commentaire'

# %%
min_review_score = df_main[['customer_unique_id','review_score']].groupby(['customer_unique_id']).min()
min_review_score = min_review_score.rename(columns = {'review_score': 'min_review_score'})
min_review_score = min_review_score.reset_index()

# %%
min_review_score.head()
# Out:
#                  customer_unique_id  min_review_score
# 0  0000366f3b9a7992bf8c76cfdf3221e2               5.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f               4.0
# 2  0000f46a3911fa3c0805444483337064               3.0
# 3  0000f6ccb0745a6a4b88665a16c9f078               4.0
# 4  0004aac84e0df4da2b147fca70cf8255               5.0

# %% [markdown]
# #### création variable 'max note commentaire'

# %%
max_review_score = df_main[['customer_unique_id','review_score']].groupby(['customer_unique_id']).max()
max_review_score = max_review_score.rename(columns = {'review_score': 'max_review_score'})
max_review_score = max_review_score.reset_index()

# %%
max_review_score.head()
# Out:
#                  customer_unique_id  max_review_score
# 0  0000366f3b9a7992bf8c76cfdf3221e2               5.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f               4.0
# 2  0000f46a3911fa3c0805444483337064               3.0
# 3  0000f6ccb0745a6a4b88665a16c9f078               4.0
# 4  0004aac84e0df4da2b147fca70cf8255               5.0

# %% [markdown]
# #### création variable 'type paiement'

# %%
type_payment = df_main[['customer_unique_id','payment_type']].groupby(['customer_unique_id'])['payment_type'].apply(lambda x: x.mode()[0])
type_payment = pd.DataFrame(type_payment)
type_payment = type_payment.reset_index()

# %% [markdown]
# #### création variable 'carte bancaire' ou 'autre moyen paiement'

# %%
#type_payment['credit card'] =\
    #(type_payment['payment_type'] == 'credit_card')

# %%
#type_payment.head()

# %%
nb_type_paiement = type_payment.groupby(['payment_type']).count()['customer_unique_id']
nb_type_paiement
# Out:
# payment_type
# boleto         18300
# credit_card    70062
# debit_card      1392
# voucher         1711
# Name: customer_unique_id, dtype: int64

# %%
plt.figure(figsize=(15,15))
plt.pie(nb_type_paiement,startangle=90,autopct='%1.0f%%',labels=['boleto','credit_card','debit_card','voucher'])
plt.legend(loc="upper right",bbox_to_anchor=(1.255, 1.15))

# %% [markdown]
# #### création variable 'nb fois de paiement'

# %%
nb_payment = df_main[['customer_unique_id','payment_installments']].groupby(['customer_unique_id']).mean()
nb_payment = nb_payment.rename(columns = {'payment_installments': 'nb_payment'})
nb_payment = nb_payment.reset_index()

# %% [markdown]
# #### création variable 'payment une seul fois' ou 'plusieurs'

# %%
#nb_payment['single_payment'] = (nb_payment['nb_payment'] == 1)

# %%
#nb_payment.head()

# %% [markdown]
# ####  création variable 'achat ville'

# %%
city_purchase = df_main[['customer_unique_id','customer_city']].groupby(['customer_unique_id'])['customer_city'].apply(lambda x: x.mode()[0])
city_purchase = pd.DataFrame(city_purchase)
city_purchase = city_purchase.reset_index()

# %%
city_purchase.head()
# Out:
#                  customer_unique_id customer_city
# 0  0000366f3b9a7992bf8c76cfdf3221e2       cajamar
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f        osasco
# 2  0000f46a3911fa3c0805444483337064      sao jose
# 3  0000f6ccb0745a6a4b88665a16c9f078         belem
# 4  0004aac84e0df4da2b147fca70cf8255      sorocaba

# %% [markdown]
# #### création variable 'achat region'

# %%
state_purchase = df_main[['customer_unique_id','customer_state']].groupby(['customer_unique_id'])['customer_state'].apply(lambda x: x.mode()[0])
state_purchase = pd.DataFrame(state_purchase)    
state_purchase = state_purchase.reset_index()

# %%
state_purchase.head()
# Out:
#                  customer_unique_id customer_state
# 0  0000366f3b9a7992bf8c76cfdf3221e2             SP
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f             SP
# 2  0000f46a3911fa3c0805444483337064             SC
# 3  0000f6ccb0745a6a4b88665a16c9f078             PA
# 4  0004aac84e0df4da2b147fca70cf8255             SP

# %%
state_purchase.nunique()
# Out:
# customer_unique_id    91465
# customer_state           27
# dtype: int64

# %%
nb_state_purchase = state_purchase.groupby(['customer_state']).count()['customer_unique_id'].sort_values(ascending=False).plot(kind='bar')
nb_state_purchase
# Out:
# <AxesSubplot:xlabel='customer_state'>

# %% [markdown]
# #### création variable 'produit le plus acheté'

# %%
most_purchased_product = df_main[['customer_unique_id','product_category_name']].groupby(['customer_unique_id'])['product_category_name'].apply(lambda x: x.mode()[0])
most_purchased_product = pd.DataFrame(most_purchased_product)
most_purchased_product = most_purchased_product.reset_index()

# %%
# Regroupement de certains types de  produit dans des catégories uniques
product_type = { 
    
                 #Mode
                 'fashion_bags_accessories' : 'Mode',
                 'luggage_accessories' : 'Mode', 
                 'computers_accessories' : 'Mode',
                 'fashion_underwear_beach' : 'Mode',
                 'housewares' : 'Mode',
                 'watches_gifts' : 'Mode',
                 'fashion_shoes' : 'Mode',
                 'fashion_male_clothing' : 'Mode',
                 'fashion_sport' : 'Mode',
                 'fashio_female_clothing':'Mode',
                 'fashion_childrens_clothes':'Mode',
                 'baby':'Mode',
    
                 #Grocery
                 'drinks':'Grocery',
                 'food_drink':'Grocery',
                 'food':'Grocery',
                
                 #Leisure
                 'books_general_interest':'Leisure',
                 'books_technical':'Leisure',
                 'books_imported':'Leisure',
                 'cine_photo':'Leisure',
                 'dvds_blu_ray':'Leisure',
                 'musical_instruments':'Leisure',
                 'cds_dvds_musicals':'Leisure',
                 'audio':'Leisure',
                 'music':'Leisure',
                 'consoles_games':'Leisure',
                 'cool_stuff':'Leisure',
                 'christmas_supplies':'Leisure',
                 'art':'Leisure',
                 'party_supplies':'Leisure',
                 'arts_and_craftmanship':'Leisure',
                 'toys':'Leisure',
                 'sports_leisure':'Leisure',
                 'pet_shop':'Leisure',
    
                 #Technologie, construction 
                 'auto':'Technologie, construction',
                 'telephony':'Technologie, construction',
                 'electronics':'Technologie, construction',
                 'fixed_telephony':'Technologie, construction',
                 'signaling_and_security':'Technologie, construction',
                 'computers':'Technologie, construction',
                 'home_appliances':'Technologie, construction',
                 'small_appliances':'Technologie, construction',
                 'home_appliances_2':'Technologie, construction',
                 'air_conditioning':'Technologie, construction',
                 'small_appliances_home_oven_and_coffee':'Technologie, construction',
                 'home_construction':'Technologie, construction',
                 'garden_tools':'Technologie, construction',
                 'construction_tools_construction':'Technologie, construction',
                 'construction_tools_safety':'Technologie, construction',
                 'construction_tools_lights':'Technologie, construction',
                 'costruction_tools_garden':'Technologie, construction',
                 'costruction_tools_tools':'Technologie, construction',
                 
    
    
                 #Home,Furniture
                 'bed_bath_table':'Home,Furniture',
                 'office_furniture':'Home,Furniture',
                 'furniture_decor':'Home,Furniture',
                 'furniture_living_room':'Home,Furniture',
                 'kitchen_dining_laundry_garden_furniture':'Home,Furniture',
                 'furniture_bedroom':'Home,Furniture',
                 'furniture_mattress_and_upholstery':'Home,Furniture',
                 'la_cuisine':'Home,Furniture',
                 'flowers':'Home,Furniture',
                 'home_confort':'Home,Furniture',
                 'home_comfort_2':'Home,Furniture',
                 'stationery':'Home,Furniture',
                 'tablets_printing_image':'Home,Furniture',
                 
    
                 #Beauty,Health,Personal Care
                 'health_beauty':'Beauty,Health,Personal Care',
                 'perfumery':'Beauty,Health,Personal Care',
                 'diapers_and_hygiene':'Beauty,Health,Personal Care',
                 
    
                 #Other
                 'industry_commerce_and_business':'other',
                 'market_place':'other',
                 'agro_industry_and_commerce':'other',
                 'security_and_services':'other'}

for key, value in product_type.items():
    most_purchased_product['product_category_name'].loc[most_purchased_product["product_category_name"].str.contains(key, case=False, regex=False)] = value

# %%
most_purchased_product.head()
# Out:
#                  customer_unique_id        product_category_name
# 0  0000366f3b9a7992bf8c76cfdf3221e2               Home,Furniture
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  Beauty,Health,Personal Care
# 2  0000f46a3911fa3c0805444483337064               Home,Furniture
# 3  0000f6ccb0745a6a4b88665a16c9f078    Technologie, construction
# 4  0004aac84e0df4da2b147fca70cf8255    Technologie, construction

# %%
most_purchased_product.nunique()
# Out:
# customer_unique_id       91465
# product_category_name        7
# dtype: int64

# %%
most_purchased_product.product_category_name.unique()
# Out:
# array(['Home,Furniture', 'Beauty,Health,Personal Care',
#        'Technologie, construction', 'Leisure', 'Mode', 'Grocery', 'other'],
#       dtype=object)

# %% [markdown]
# ##### création variable 'heure d'achat'

# %%
purchase_hour = df_main[['customer_unique_id','order_purchase_timestamp','order_delivered_customer_date']].groupby(['customer_unique_id']).head(5)
purchase_hour['order_purchase_timestamp'] = purchase_hour['order_purchase_timestamp'].astype('datetime64')
#purchase_month['purchase_month'] = purchase_month['order_purchase_timestamp'].apply(lambda x: x.month())
purchase_hour['purchase_hour'] = purchase_hour['order_purchase_timestamp'].dt.hour
purchase_hour = purchase_hour.drop(['order_purchase_timestamp','order_delivered_customer_date'],axis=1)

# %%
purchase_hour.head()
# Out:
#                  customer_unique_id  purchase_hour
# 0  7c396fd4830fd04220f754e42b4e5bff             10
# 1  7c396fd4830fd04220f754e42b4e5bff             10
# 2  7c396fd4830fd04220f754e42b4e5bff             10
# 3  af07308b275d755c9edb36a90c618231             20
# 4  3a653a41f6f9fc3d2a113cf8398680e8              8

# %% [markdown]
# #### création variable 'jour d'achat'

# %%
purchase_day = df_main[['customer_unique_id','order_purchase_timestamp','order_delivered_customer_date']].groupby(['customer_unique_id']).head(5)
purchase_day['order_purchase_timestamp'] = purchase_day['order_purchase_timestamp'].astype('datetime64')
purchase_day['purchase_day'] = purchase_day['order_purchase_timestamp'].apply(lambda x: x.weekday())
purchase_day = purchase_day.drop(['order_purchase_timestamp','order_delivered_customer_date'],axis=1)

# %%
purchase_day.head()
# Out:
#                  customer_unique_id  purchase_day
# 0  7c396fd4830fd04220f754e42b4e5bff             0
# 1  7c396fd4830fd04220f754e42b4e5bff             0
# 2  7c396fd4830fd04220f754e42b4e5bff             0
# 3  af07308b275d755c9edb36a90c618231             1
# 4  3a653a41f6f9fc3d2a113cf8398680e8             2

# %% [markdown]
# #### création variable 'mois d'achat'

# %%
purchase_month = df_main[['customer_unique_id','order_purchase_timestamp','order_delivered_customer_date']].groupby(['customer_unique_id']).head(5)
purchase_month['order_purchase_timestamp'] = purchase_month['order_purchase_timestamp'].astype('datetime64')
#purchase_month['purchase_month'] = purchase_month['order_purchase_timestamp'].apply(lambda x: x.month())
purchase_month['purchase_month'] = purchase_month['order_purchase_timestamp'].dt.month
purchase_month = purchase_month.drop(['order_purchase_timestamp','order_delivered_customer_date'],axis=1)

# %%
purchase_month.head()
# Out:
#                  customer_unique_id  purchase_month
# 0  7c396fd4830fd04220f754e42b4e5bff              10
# 1  7c396fd4830fd04220f754e42b4e5bff              10
# 2  7c396fd4830fd04220f754e42b4e5bff              10
# 3  af07308b275d755c9edb36a90c618231               7
# 4  3a653a41f6f9fc3d2a113cf8398680e8               8

# %% [markdown]
# #### création variable 'délai livraison'

# %%
# Transformer les variables représentant des dates/heures en Datetime
cols = ['order_purchase_timestamp', 'order_approved_at',
        'order_delivered_carrier_date', 'order_delivered_customer_date',
        'order_estimated_delivery_date']
for col in cols:
    df_main[col] = pd.to_datetime(df_main[col],
                                    format='%Y-%m-%d %H:%M:%S')

# %%
deadline_order = df_main[['customer_unique_id','order_purchase_timestamp','order_delivered_customer_date']].groupby(['customer_unique_id']).head(5)
deadline_order['order_purchase_timestamp'] = deadline_order['order_purchase_timestamp'].astype('datetime64')
deadline_order['order_delivered_customer_date'] = pd.to_datetime(deadline_order['order_delivered_customer_date'],errors='coerce')
deadline_order['deadline_order'] = deadline_order['order_delivered_customer_date']- deadline_order['order_purchase_timestamp']
deadline_order = deadline_order.drop(['order_purchase_timestamp','order_delivered_customer_date'],axis=1)

# %%
deadline_order.head()
# Out:
#                  customer_unique_id   deadline_order
# 0  7c396fd4830fd04220f754e42b4e5bff  8 days 10:28:40
# 1  7c396fd4830fd04220f754e42b4e5bff  8 days 10:28:40
# 2  7c396fd4830fd04220f754e42b4e5bff  8 days 10:28:40
# 3  af07308b275d755c9edb36a90c618231 13 days 18:46:08
# 4  3a653a41f6f9fc3d2a113cf8398680e8  9 days 09:27:40

# %% [markdown]
# #### création variable 'taille du commentaire'

# %%
# taille du commentaire

for label, row in df_main.iterrows():
    df_main.loc[label, 'longeur_du_commentaire'] =len(row['review_comment_message'])
taille_commentaire = df_main[['customer_unique_id','longeur_du_commentaire']].groupby(['customer_unique_id']).mean()
taille_commentaire = taille_commentaire.reset_index()

# %%
taille_commentaire.head()
# Out:
#                  customer_unique_id  longeur_du_commentaire
# 0  0000366f3b9a7992bf8c76cfdf3221e2                   111.0
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f                     8.0
# 2  0000f46a3911fa3c0805444483337064                     8.0
# 3  0000f6ccb0745a6a4b88665a16c9f078                    12.0
# 4  0004aac84e0df4da2b147fca70cf8255                     8.0

# %%
end_date = max(df_main['order_purchase_timestamp']) + dt.timedelta(days=1)

df_rfm = df_main.groupby('customer_unique_id').agg(
    #la durée entre une date de référence et la dernière date d'achat de chaque client
    recency=('order_purchase_timestamp', lambda x: (end_date - x.max()).days),
    #le nombre de fois où votre client a fait une transaction pendant une période donnée donc 
    #le nombre de commande sur la période de l'étude
    #frequency=('customer_unique_id', 'count'),
    frequency=('order_id', 'count'),
    #la somme des dépenses de votre client
    monetary=('payment_value', 'sum')
).reset_index()

df_rfm.head()
# Out:
#                  customer_unique_id  recency  frequency  monetary
# 0  0000366f3b9a7992bf8c76cfdf3221e2      112          1    141.90
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f      115          1     27.19
# 2  0000f46a3911fa3c0805444483337064      537          1     86.22
# 3  0000f6ccb0745a6a4b88665a16c9f078      321          1     43.62
# 4  0004aac84e0df4da2b147fca70cf8255      288          1    196.89

# %%
end_date
# Out:
# Timestamp('2018-08-30 15:00:37')

# %%
df_main_bis = pd.DataFrame()

# %%
df_main_bis = (
    
                    # The main df is base one the rfm dataframe
                    df_rfm
                    # merge average_purchase dataframe
                    .merge(average_purchase, how = 'left', on = 'customer_unique_id')
    
                    #Merge min_purchase dataframe
                    .merge(min_purchase, how = 'left', on = 'customer_unique_id')
    
                    #Merge max_purchase dataframe
                    .merge(max_purchase, how = 'left', on = 'customer_unique_id')
                    
                    #Merge nb_item_per_customer dataframe
                    .merge(nb_item_per_customer, how = 'left', on = 'customer_unique_id')
    
                    #Merge nb_cde_per_customer dataframe
                    .merge(nb_cde_per_customer, how = 'left', on = 'customer_unique_id')
    
                    #Merge average_review_score dataframe
                    .merge(average_review_score, how = 'left', on = 'customer_unique_id')
    
                    #Merge minimum_review_score dataframe
                    .merge(min_review_score, how = 'left', on = 'customer_unique_id')
                    
                    
                    #Merge maximum_review_score dataframe
                    .merge(max_review_score, how = 'left', on = 'customer_unique_id')
    
    
                    #Merge type_payment dataframe
                    .merge(type_payment, how = 'left', on = 'customer_unique_id')
                    
                    #Merge nb_payment dataframe
                    .merge(nb_payment, how = 'left', on = 'customer_unique_id')
    
    
                    #Merge ville achat dataframe
                    .merge(city_purchase, how = 'left', on = 'customer_unique_id')
    
                    #Merge région achat dataframe
                    .merge(state_purchase, how = 'left', on = 'customer_unique_id')
    
                    #Merge délais livraison dataframe
                    .merge(deadline_order, how = 'left', on = 'customer_unique_id')
    
                    #Merge jour achat dataframe
                    .merge(purchase_day, how = 'left', on = 'customer_unique_id')
    
                    #Merge mois achat dataframe
                    .merge(purchase_month, how = 'left', on = 'customer_unique_id')
    
                    #Merge heure achat dataframe
                    .merge(purchase_hour, how = 'left', on = 'customer_unique_id')
                
                    #Merge most_purchased_product dataframe
                    .merge(most_purchased_product, how = 'left', on = 'customer_unique_id')
    
    
                    #Merge most_purchased_product dataframe
                    .merge(taille_commentaire, how = 'left', on = 'customer_unique_id')





)

# %%
df_main_bis = df_main_bis.drop_duplicates(['customer_unique_id'])

# %%
df_main_bis.head(20)
# Out:
#                   customer_unique_id  recency  frequency  monetary  \
# 0   0000366f3b9a7992bf8c76cfdf3221e2      112          1    141.90
# 1   0000b849f77a49e4a4ce2b2a4ca5be3f      115          1     27.19
# 2   0000f46a3911fa3c0805444483337064      537          1     86.22
# 3   0000f6ccb0745a6a4b88665a16c9f078      321          1     43.62
# 4   0004aac84e0df4da2b147fca70cf8255      288          1    196.89
# 5   0004bd2a26a76fe21f786e4fbd80607f      146          1    166.98
# 6   00050ab1314c0e55a6ca13cf7181fecf      132          1     35.38
# 7   00053a61a98854899e70ed204dd4bafe      183          2    838.36
# 23  0005e1862207bf6ccc02e4228effd9a0      543          1    150.12
# 24  0005ef4cd20d2893f0d9fbd94d3c0d97      170          1    129.76
# 25  0006fdc98a402fceb4eb0ee528f6a8d4      408          1     29.00
# 26  00082cbe03e478190aadbea78542e933      283          1    126.26
# 27  00090324bbad0e9342388303bb71ba0a      159          1     63.66
# 28  000949456b182f53c18b68d6babc79c1      129          1     82.05
# 29  000a5ad9c4601d2bbdd9ed765d5213b3      384          1     91.28
# 30  000bfa1d2f1a41876493be685390d6d3      335          2     93.70
# 46  000c8bdb58a29e7115cfc257230fb21b      260          1     29.00
# 47  000d460961d6dbfa3ec6c9f5805769e1      234          1     36.68
# 48  000de6019bb59f34c099a907c151d855      377          2    514.88
# 64  000e309254ab1fc5ba99dd469d36bdb4       66          2     78.42
#
#     average_purchase  min_purchase  max_purchase  nb_item_per_customer  \
# 0             129.90        129.90        129.90                     1
# 1              18.90         18.90         18.90                     1
# 2              69.00         69.00         69.00                     1
# 3              25.99         25.99         25.99                     1
# 4             180.00        180.00        180.00                     1
# 5             154.00        154.00        154.00                     1
# 6              27.99         27.99         27.99                     1
# 7             191.00        191.00        191.00                     2
# 23            135.00        135.00        135.00                     1
# 24            104.90        104.90        104.90                     1
# 25             13.90         13.90         13.90                     1
# 26             79.00         79.00         79.00                     1
# 27             49.95         49.95         49.95                     1
# 28             64.89         64.89         64.89                     1
# 29             76.99         76.99         76.99                     1
# 30             35.00         35.00         35.00                     2
# 46             13.90         13.90         13.90                     1
# 47             28.90         28.90         28.90                     1
# 48            114.90         89.90        139.90                     2
# 64             59.90         59.90         59.90                     2
#
#     nb_cde_per_customer  average_review_score  min_review_score  \
# 0                     1                   5.0               5.0
# 1                     1                   4.0               4.0
# 2                     1                   3.0               3.0
# 3                     1                   4.0               4.0
# 4                     1                   5.0               5.0
# 5                     1                   4.0               4.0
# 6                     1                   4.0               4.0
# 7                     2                   1.0               1.0
# 23                    1                   4.0               4.0
# 24                    1                   1.0               1.0
# 25                    1                   3.0               3.0
# 26                    1                   5.0               5.0
# 27                    1                   5.0               5.0
# 28                    1                   4.0               4.0
# 29                    1                   4.0               4.0
# 30                    2                   4.5               4.0
# 46                    1                   5.0               5.0
# 47                    1                   5.0               5.0
# 48                    2                   2.0               2.0
# 64                    2                   3.0               3.0
#
#     max_review_score payment_type  nb_payment          customer_city  \
# 0                5.0  credit_card         8.0                cajamar
# 1                4.0  credit_card         1.0                 osasco
# 2                3.0  credit_card         8.0               sao jose
# 3                4.0  credit_card         4.0                  belem
# 4                5.0  credit_card         6.0               sorocaba
# 5                4.0  credit_card         8.0              sao paulo
# 6                4.0       boleto         1.0               campinas
# 7                1.0  credit_card         3.0               curitiba
# 23               4.0  credit_card         3.0            teresopolis
# 24               1.0  credit_card         4.0               sao luis
# 25               3.0  credit_card         2.0          mimoso do sul
# 26               5.0       boleto         1.0                itapeva
# 27               5.0  credit_card         3.0               campinas
# 28               4.0       boleto         1.0  sao bernardo do campo
# 29               4.0  credit_card         3.0           porto alegre
# 30               5.0  credit_card         4.0                 santos
# 46               5.0  credit_card         2.0         belo horizonte
# 47               5.0  credit_card         1.0              sao paulo
# 48               2.0  credit_card         4.0          sao sebastiao
# 64               3.0  credit_card         1.0    valparaiso de goias
#
#    customer_state   deadline_order  purchase_day  purchase_month  \
# 0              SP  6 days 09:52:10             3               5
# 1              SP  3 days 06:51:15             0               5
# 2              SC 25 days 17:33:44             4               3
# 3              PA 20 days 00:53:24             3              10
# 4              SP 13 days 03:23:14             1              11
# 5              SP  1 days 20:39:27             3               4
# 6              SP  6 days 23:11:36             4               4
# 7              PR 16 days 07:47:10             2               2
# 23             RJ  4 days 09:00:56             5               3
# 24             MA 53 days 21:16:26             0               3
# 25             ES 16 days 09:19:39             1               7
# 26             SP 10 days 06:33:27             6              11
# 27             SP 15 days 22:51:01             5               3
# 28             SP  7 days 05:39:17             0               4
# 29             RS 11 days 07:12:42             4               8
# 30             SP 13 days 23:03:09             4               9
# 46             MG 14 days 02:43:37             1              12
# 47             SP  3 days 23:20:58             6               1
# 48             SP  4 days 00:08:09             3               8
# 64             GO 14 days 13:10:34             0               6
#
#     purchase_hour        product_category_name  longeur_du_commentaire
# 0              10               Home,Furniture                   111.0
# 1              11  Beauty,Health,Personal Care                     8.0
# 2              21               Home,Furniture                     8.0
# 3              20    Technologie, construction                    12.0
# 4              19    Technologie, construction                     8.0
# 5              19    Technologie, construction                     8.0
# 6              12    Technologie, construction                     8.0
# 7              11                      Leisure                   198.0
# 23             23                         Mode                     8.0
# 24             15                      Leisure                   122.0
# 25              9               Home,Furniture                    47.0
# 26             15                         Mode                     8.0
# 27             14               Home,Furniture                    74.0
# 28              9                         Mode                     8.0
# 29             13  Beauty,Health,Personal Care                     8.0
# 30             14                         Mode                    26.0
# 46             22               Home,Furniture                    62.0
# 47             22    Technologie, construction                     8.0
# 48             19               Home,Furniture                   136.0
# 64              9                         Mode                     8.0

# %%
#df_main_bis.frequency.sort_values(ascending = False)

# %%
#df_main_bis.nb_item_per_customer.sort_values(ascending = False)

# %%
#df_main_bis.nb_cde_per_customer.sort_values(ascending = False)

# %%
df_main_bis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91465 entries, 0 to 1163368
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_unique_id      91465 non-null  object
#  1   recency                 91465 non-null  int64
#  2   frequency               91465 non-null  int64
#  3   monetary                91465 non-null  float64
#  4   average_purchase        91465 non-null  float64
#  5   min_purchase            91465 non-null  float64
#  6   max_purchase            91465 non-null  float64
#  7   nb_item_per_customer    91465 non-null  int64
#  8   nb_cde_per_customer     91465 non-null  int64
#  9   average_review_score    91465 non-null  float64
#  10  min_review_score        91465 non-null  float64
#  11  max_review_score        91465 non-null  float64
#  12  payment_type            91465 non-null  object
#  13  nb_payment              91465 non-null  float64
#  14  customer_city           91465 non-null  object
#  15  customer_state          91465 non-null  object
#  16  deadline_order          91465 non-null  timedelta64[ns]
#  17  purchase_day            91465 non-null  int64
#  18  purchase_month          91465 non-null  int64
#  19  purchase_hour           91465 non-null  int64
#  20  product_category_name   91465 non-null  object
#  21  longeur_du_commentaire  91465 non-null  float64
# dtypes: float64(9), int64(7), object(5), timedelta64[ns](1)
# memory usage: 16.0+ MB

# %%
#maximum 8 catégorie , donc faut re voir les regroupement

# %%
df_main_bis.shape
# Out:
# (91465, 22)

# %%
df_main_bis.isna().sum()
# Out:
# customer_unique_id        0
# recency                   0
# frequency                 0
# monetary                  0
# average_purchase          0
# min_purchase              0
# max_purchase              0
# nb_item_per_customer      0
# nb_cde_per_customer       0
# average_review_score      0
# min_review_score          0
# max_review_score          0
# payment_type              0
# nb_payment                0
# customer_city             0
# customer_state            0
# deadline_order            0
# purchase_day              0
# purchase_month            0
# purchase_hour             0
# product_category_name     0
# longeur_du_commentaire    0
# dtype: int64

# %%
df_main_bis.describe().T
# Out:
#                           count                        mean  \
# recency                 91465.0                  237.094091
# frequency               91465.0                    1.237555
# monetary                91465.0                  212.312425
# average_purchase        91465.0                  125.668189
# min_purchase            91465.0                  124.001776
# max_purchase            91465.0                  127.537369
# nb_item_per_customer    91465.0                    1.237555
# nb_cde_per_customer     91465.0                    1.237555
# average_review_score    91465.0                    4.154585
# min_review_score        91465.0                    4.143574
# max_review_score        91465.0                    4.165889
# nb_payment              91465.0                    2.903331
# deadline_order            91465  12 days 12:32:10.796599792
# purchase_day            91465.0                    2.755841
# purchase_month          91465.0                    6.038583
# purchase_hour           91465.0                   14.786541
# longeur_du_commentaire  91465.0                   32.147941
#
#                                               std              min  \
# recency                                 152.57865              1.0
# frequency                                0.844384              1.0
# monetary                               631.309409             9.59
# average_purchase                       188.657777             0.85
# min_purchase                           188.168262             0.85
# max_purchase                           190.774299             0.85
# nb_item_per_customer                     0.844384              1.0
# nb_cde_per_customer                      0.844384              1.0
# average_review_score                     1.279334              1.0
# min_review_score                          1.29159              1.0
# max_review_score                         1.277407              1.0
# nb_payment                               2.679822              0.0
# deadline_order          9 days 11:36:32.624901990  0 days 12:48:07
# purchase_day                             1.966942              0.0
# purchase_month                           3.218118              1.0
# purchase_hour                            5.318199              0.0
# longeur_du_commentaire                  44.542601              1.0
#
#                                     25%               50%               75%  \
# recency                           114.0             218.0             345.0
# frequency                           1.0               1.0               1.0
# monetary                          63.84            112.84            202.76
# average_purchase                   42.9              79.0             139.9
# min_purchase                      39.99              77.9             139.0
# max_purchase                      43.75              79.9            139.99
# nb_item_per_customer                1.0               1.0               1.0
# nb_cde_per_customer                 1.0               1.0               1.0
# average_review_score                4.0               5.0               5.0
# min_review_score                    4.0               5.0               5.0
# max_review_score                    4.0               5.0               5.0
# nb_payment                          1.0               2.0               4.0
# deadline_order          6 days 18:11:21  10 days 04:49:21  15 days 16:23:16
# purchase_day                        1.0               3.0               4.0
# purchase_month                      3.0               6.0               8.0
# purchase_hour                      11.0              15.0              19.0
# longeur_du_commentaire              8.0               8.0              40.0
#
#                                       max
# recency                             695.0
# frequency                            75.0
# monetary                        109312.64
# average_purchase                   6735.0
# min_purchase                       6735.0
# max_purchase                       6735.0
# nb_item_per_customer                 75.0
# nb_cde_per_customer                  75.0
# average_review_score                  5.0
# min_review_score                      5.0
# max_review_score                      5.0
# nb_payment                           24.0
# deadline_order          208 days 08:26:32
# purchase_day                          6.0
# purchase_month                       12.0
# purchase_hour                        23.0
# longeur_du_commentaire              208.0

# %%
# Export des données nettoyées sans pré-processing
df_main_bis.to_csv('OLIST_data_exploratoire.csv',index = False)

# %%
df_temp = df_main_bis[df_main_bis['purchase_month']].sort_values(by='purchase_month').copy()
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(df_temp['purchase_month'], df_temp['monetary'])
plt.title('transaction')
#plt.savefig("transaction_categ_1_octobre.jpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-7effb20d3951> in <module>
# ----> 1 df_temp = df_main_bis[df_main_bis['purchase_month']].sort_values(by='purchase_month').copy()
#       2 fig, ax = plt.subplots(figsize=(15,5))
#       3 ax.bar(df_temp['purchase_month'], df_temp['monetary'])
#       4 plt.title('transaction')
#       5 #plt.savefig("transaction_categ_1_octobre.jpg")
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Int64Index([ 5,  5,  3, 10, 11,  4,  4,  2,  3,  3,\n            ...\n             9, 12,  8, 10, 12,  6, 12,  2,  5,  5],\n           dtype='int64', length=91465)] are in the [columns]"

# %%
# il vaut mieux utiliser elbow méthode/ faut montrer aussi silouette
